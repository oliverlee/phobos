# %%
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plot_sim as ps

#%matplotlib notebook
# %matplotlib inline 

# %load_ext autoreload
# %autoreload 2

DEFAULT_FIGSIZE = (12, 8)
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = DEFAULT_FIGSIZE

# %%
plt.close('all')
log = ps.ProcessedRecord('../tools/build/log.pb.cobs')
fig, ax = plt.subplots()
ax.plot(log.records.sensors.kistler_measured_torque)

log.plot_states(degrees=True)
log.plot_controller_states(degrees=True)
# kistler torque scaled down due to changes in saconfig
log.plot_torque_signals()
plt.show()

# %%
log = ps.ProcessedRecord('../tools/build/log_r2_motoroff.pb.cobs')
plt.close('all')
fig, ax = plt.subplots()
ax.plot(log.records.sensors.kistler_measured_torque)

#log.plot_states(degrees=True)
#log.plot_controller_states(degrees=True)
log.plot_torque_signals()
plt.show()

# %%
log = ps.ProcessedRecord('../tools/build/log_r2.pb.cobs')
plt.close('all')
fig, ax = plt.subplots()
ax.plot(log.records.sensors.kistler_measured_torque)

log.plot_states(degrees=True)
log.plot_controller_states(degrees=True)
log.plot_torque_signals()
plt.show()
