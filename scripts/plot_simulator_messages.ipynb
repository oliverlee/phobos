# %%
import sys

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plot_sim as ps

# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#log = ps.ProcessedRecord('../tools/build/log.pb.cobs')
plt.close('all')
log.plot_states(degrees=True)
log.plot_controller_states(degrees=True)
log.plot_torque_signals()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# <img src="data:image/png;base64,..." width="892.7778014283127">
# <img src="data:image/png;base64,..." width="575.5555708025713">

# %%
sns.palplot(log.colors)
# Out:
# <img src="data:image/png;base64,..." width="719.4444635032141">
